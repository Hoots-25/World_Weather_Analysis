# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
from datetime import datetime
import requests
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low = -90.000, high = 90.000, size = 2000)
lngs = np.random.uniform(low = -180.000, high = 180.000, size = 2000)
lat_lngs = zip(lats, lngs)

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 794

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
    
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except Exception as ex:
        print("City not found. Skipping...")
        print(ex)
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | jamestown
# Processing Record 2 of Set 1 | qaanaaq
# Processing Record 3 of Set 1 | hilo
# Processing Record 4 of Set 1 | krasnoselkup
# Processing Record 5 of Set 1 | ikongo
# Processing Record 6 of Set 1 | touros
# Processing Record 7 of Set 1 | corsicana
# Processing Record 8 of Set 1 | saskylakh
# Processing Record 9 of Set 1 | georgetown
# Processing Record 10 of Set 1 | rikitea
# Processing Record 11 of Set 1 | bolungarvik
# City not found. Skipping...
# 'coord'
# Processing Record 12 of Set 1 | port alfred
# Processing Record 13 of Set 1 | nador
# Processing Record 14 of Set 1 | kapaa
# Processing Record 15 of Set 1 | palmer
# Processing Record 16 of Set 1 | hasama
# City not found. Skipping...
# 'coord'
# Processing Record 17 of Set 1 | provideniya
# Processing Record 18 of Set 1 | attawapiskat
# City not found. Skipping...
# 'coord'
# Processing Record 19 of Set 1 | ushuaia
# Processing Record 20 of Set 1 | airai
# Processing Record 21 of Set 1 | yakima
# Processing Record 22 of Set 1 | ziarat
# Processing Record 23 of Set 1 | mataura
# Processing Record 24 of Set 1 | tual
# Processing Record 25 of Set 1 | nikolskoye
# Processing Record 26 of Set 1 | hualmay
# Processing Record 27 of Set 1 | grand river south east
# City not found. Skipping...
# 'coord'
# Processing Record 28 of Set 1 | husavik
# Processing Record 29 of Set 1 | mar del plata
# Processing Record 30 of Set 1 | marawi
# Processing Record 31 of Set 1 | kaka
# Processing Record 32 of Set 1 | fairbanks
# Processing Record 33 of Set 1 | gemena
# Processing Record 34 of Set 1 | avarua
# Processing Record 35 of Set 1 | atuona
# Processing Record 36 of Set 1 | lebu
# Processing Record 37 of Set 1 | san patricio
# Processing Record 38 of Set 1 | yinchuan
# Processing Record 39 of Set 1 | barrow
# Processing Record 40 of Set 1 | adrar
# Processing Record 41 of Set 1 | guerrero negro
# Processing Record 42 of Set 1 | agbor
# Processing Record 43 of Set 1 | pangnirtung
# Processing Record 44 of Set 1 | atherton
# Processing Record 45 of Set 1 | sulangan
# Processing Record 46 of Set 1 | kaeo
# Processing Record 47 of Set 1 | taolanaro
# City not found. Skipping...
# 'coord'
# Processing Record 48 of Set 1 | hobart
# Processing Record 49 of Set 1 | albany
# Processing Record 50 of Set 1 | arraial do cabo
# Processing Record 1 of Set 2 | ust-kamchatsk
# City not found. Skipping...
# 'coord'
# Processing Record 2 of Set 2 | siavonga
# Processing Record 3 of Set 2 | svarstad
# Processing Record 4 of Set 2 | sao miguel do araguaia
# Processing Record 5 of Set 2 | filadelfia
# Processing Record 6 of Set 2 | busselton
# Processing Record 7 of Set 2 | butaritari
# Processing Record 8 of Set 2 | penzance
# Processing Record 9 of Set 2 | thompson
# Processing Record 10 of Set 2 | sovetskiy
# Processing Record 11 of Set 2 | zyryanka
# Processing Record 12 of Set 2 | caravelas
# Processing Record 13 of Set 2 | codrington
# Processing Record 14 of Set 2 | asfi
# Processing Record 15 of Set 2 | katangli
# Processing Record 16 of Set 2 | waipawa
# Processing Record 17 of Set 2 | matamoros
# Processing Record 18 of Set 2 | yerbogachen
# Processing Record 19 of Set 2 | blagoyevo
# Processing Record 20 of Set 2 | artyk
# City not found. Skipping...
# 'coord'
# Processing Record 21 of Set 2 | high wycombe
# Processing Record 22 of Set 2 | bredasdorp
# Processing Record 23 of Set 2 | loncoche
# Processing Record 24 of Set 2 | saint george
# Processing Record 25 of Set 2 | punta arenas
# Processing Record 26 of Set 2 | coihaique
# Processing Record 27 of Set 2 | hithadhoo
# Processing Record 28 of Set 2 | yulara
# Processing Record 29 of Set 2 | nanortalik
# Processing Record 30 of Set 2 | acapulco
# Processing Record 31 of Set 2 | novobureyskiy
# Processing Record 32 of Set 2 | isangel
# Processing Record 33 of Set 2 | lobito
# Processing Record 34 of Set 2 | ancud
# Processing Record 35 of Set 2 | cabo san lucas
# Processing Record 36 of Set 2 | sitka
# Processing Record 37 of Set 2 | palotina
# Processing Record 38 of Set 2 | upernavik
# Processing Record 39 of Set 2 | pevek
# Processing Record 40 of Set 2 | dudinka
# Processing Record 41 of Set 2 | tuatapere
# Processing Record 42 of Set 2 | ilulissat
# Processing Record 43 of Set 2 | karaul
# City not found. Skipping...
# 'coord'
# Processing Record 44 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# 'coord'
# Processing Record 45 of Set 2 | lompoc
# Processing Record 46 of Set 2 | pilar
# Processing Record 47 of Set 2 | pisco
# Processing Record 48 of Set 2 | tiarei
# Processing Record 49 of Set 2 | yellowknife
# Processing Record 50 of Set 2 | buala
# Processing Record 1 of Set 3 | vera cruz
# Processing Record 2 of Set 3 | vaini
# Processing Record 3 of Set 3 | cap malheureux
# Processing Record 4 of Set 3 | shimoda
# Processing Record 5 of Set 3 | bluff
# Processing Record 6 of Set 3 | victoria
# Processing Record 7 of Set 3 | coahuayana
# Processing Record 8 of Set 3 | bumba
# Processing Record 9 of Set 3 | karamea
# City not found. Skipping...
# 'coord'
# Processing Record 10 of Set 3 | cape town
# Processing Record 11 of Set 3 | leningradskiy
# Processing Record 12 of Set 3 | rjukan
# Processing Record 13 of Set 3 | raudeberg
# Processing Record 14 of Set 3 | manokwari
# Processing Record 15 of Set 3 | namatanai
# Processing Record 16 of Set 3 | labutta
# City not found. Skipping...
# 'coord'
# Processing Record 17 of Set 3 | soyo
# Processing Record 18 of Set 3 | port elizabeth
# Processing Record 19 of Set 3 | rawannawi
# City not found. Skipping...
# 'coord'
# Processing Record 20 of Set 3 | yamada
# Processing Record 21 of Set 3 | kruisfontein
# Processing Record 22 of Set 3 | agadir
# Processing Record 23 of Set 3 | matara
# Processing Record 24 of Set 3 | alofi
# Processing Record 25 of Set 3 | rocha
# Processing Record 26 of Set 3 | tsihombe
# City not found. Skipping...
# 'coord'
# Processing Record 27 of Set 3 | dalianwan
# Processing Record 28 of Set 3 | saleaula
# City not found. Skipping...
# 'coord'
# Processing Record 29 of Set 3 | ribeira grande
# Processing Record 30 of Set 3 | angoram
# Processing Record 31 of Set 3 | cayenne
# Processing Record 32 of Set 3 | marrakesh
# Processing Record 33 of Set 3 | port hardy
# Processing Record 34 of Set 3 | kuandian
# Processing Record 35 of Set 3 | broome
# Processing Record 36 of Set 3 | geraldton
# Processing Record 37 of Set 3 | apiai
# Processing Record 38 of Set 3 | marcona
# City not found. Skipping...
# 'coord'
# Processing Record 39 of Set 3 | beppu
# Processing Record 40 of Set 3 | hamilton
# Processing Record 41 of Set 3 | mandera
# Processing Record 42 of Set 3 | luderitz
# Processing Record 43 of Set 3 | malwan
# City not found. Skipping...
# 'coord'
# Processing Record 44 of Set 3 | castro
# Processing Record 45 of Set 3 | snyder
# Processing Record 46 of Set 3 | hermanus
# Processing Record 47 of Set 3 | bokspits
# City not found. Skipping...
# 'coord'
# Processing Record 48 of Set 3 | kangaba
# Processing Record 49 of Set 3 | bubaque
# Processing Record 50 of Set 3 | killybegs
# Processing Record 1 of Set 4 | ketchikan
# Processing Record 2 of Set 4 | youkounkoun
# Processing Record 3 of Set 4 | aykhal
# Processing Record 4 of Set 4 | warqla
# City not found. Skipping...
# 'coord'
# Processing Record 5 of Set 4 | bambous virieux
# Processing Record 6 of Set 4 | tautira
# Processing Record 7 of Set 4 | goksun
# Processing Record 8 of Set 4 | moree
# Processing Record 9 of Set 4 | shingu
# Processing Record 10 of Set 4 | papara
# Processing Record 11 of Set 4 | itoman
# Processing Record 12 of Set 4 | mys shmidta
# City not found. Skipping...
# 'coord'
# Processing Record 13 of Set 4 | gasa
# Processing Record 14 of Set 4 | cockburn harbour
# City not found. Skipping...
# 'coord'
# Processing Record 15 of Set 4 | gat
# Processing Record 16 of Set 4 | lata
# Processing Record 17 of Set 4 | east london
# Processing Record 18 of Set 4 | la macarena
# Processing Record 19 of Set 4 | carnarvon
# Processing Record 20 of Set 4 | blankenberge
# Processing Record 21 of Set 4 | vardo
# Processing Record 22 of Set 4 | puerto ayora
# Processing Record 23 of Set 4 | talavera
# Processing Record 24 of Set 4 | labuhan
# Processing Record 25 of Set 4 | belushya guba
# City not found. Skipping...
# 'coord'
# Processing Record 26 of Set 4 | iqaluit
# Processing Record 27 of Set 4 | kodiak
# Processing Record 28 of Set 4 | pacific grove
# Processing Record 29 of Set 4 | shibetsu
# Processing Record 30 of Set 4 | coquimbo
# Processing Record 31 of Set 4 | san quintin
# Processing Record 32 of Set 4 | guicheng
# City not found. Skipping...
# 'coord'
# Processing Record 33 of Set 4 | luwuk
# Processing Record 34 of Set 4 | barentsburg
# City not found. Skipping...
# 'coord'
# Processing Record 35 of Set 4 | ostrovnoy
# Processing Record 36 of Set 4 | port macquarie
# Processing Record 37 of Set 4 | tiksi
# Processing Record 38 of Set 4 | rincon
# Processing Record 39 of Set 4 | dno
# Processing Record 40 of Set 4 | pergamino
# Processing Record 41 of Set 4 | fort nelson
# Processing Record 42 of Set 4 | muravlenko
# Processing Record 43 of Set 4 | chuy
# Processing Record 44 of Set 4 | prince rupert
# Processing Record 45 of Set 4 | stephenville
# Processing Record 46 of Set 4 | seymchan
# Processing Record 47 of Set 4 | russkaya polyana
# Processing Record 48 of Set 4 | kargasok
# Processing Record 49 of Set 4 | esperance
# Processing Record 50 of Set 4 | hirara
# Processing Record 1 of Set 5 | makakilo city
# Processing Record 2 of Set 5 | sambava
# Processing Record 3 of Set 5 | vila franca do campo
# Processing Record 4 of Set 5 | prado
# Processing Record 5 of Set 5 | urumqi
# Processing Record 6 of Set 5 | staryy nadym
# Processing Record 7 of Set 5 | lalmohan
# Processing Record 8 of Set 5 | ballitoville
# Processing Record 9 of Set 5 | teya
# Processing Record 10 of Set 5 | cidreira
# Processing Record 11 of Set 5 | klaksvik
# Processing Record 12 of Set 5 | santa maria
# Processing Record 13 of Set 5 | saint-joseph
# Processing Record 14 of Set 5 | palana
# Processing Record 15 of Set 5 | tubuala
# Processing Record 16 of Set 5 | qasigiannguit
# Processing Record 17 of Set 5 | mataram
# Processing Record 18 of Set 5 | faya
# Processing Record 19 of Set 5 | nizhneyansk
# City not found. Skipping...
# 'coord'
# Processing Record 20 of Set 5 | umzimvubu
# City not found. Skipping...
# 'coord'
# Processing Record 21 of Set 5 | svetlogorsk
# Processing Record 22 of Set 5 | kijang
# Processing Record 23 of Set 5 | sciacca
# Processing Record 24 of Set 5 | hvammstangi
# City not found. Skipping...
# 'coord'
# Processing Record 25 of Set 5 | fortuna
# Processing Record 26 of Set 5 | ye
# City not found. Skipping...
# 'coord'
# Processing Record 27 of Set 5 | fallon
# Processing Record 28 of Set 5 | ucluelet
# Processing Record 29 of Set 5 | tessalit
# Processing Record 30 of Set 5 | odienne
# Processing Record 31 of Set 5 | adana
# Processing Record 32 of Set 5 | bucksport
# Processing Record 33 of Set 5 | torbay
# Processing Record 34 of Set 5 | poso
# Processing Record 35 of Set 5 | tabas
# Processing Record 36 of Set 5 | lesosibirsk
# Processing Record 37 of Set 5 | acandi
# Processing Record 38 of Set 5 | huarmey
# Processing Record 39 of Set 5 | sentyabrskiy
# City not found. Skipping...
# 'coord'
# Processing Record 40 of Set 5 | norman wells
# Processing Record 41 of Set 5 | bethel
# Processing Record 42 of Set 5 | abu dhabi
# Processing Record 43 of Set 5 | emirdag
# Processing Record 44 of Set 5 | baruun-urt
# Processing Record 45 of Set 5 | san carlos del zulia
# Processing Record 46 of Set 5 | kurumkan
# Processing Record 47 of Set 5 | son la
# Processing Record 48 of Set 5 | warrnambool
# Processing Record 49 of Set 5 | cabra
# Processing Record 50 of Set 5 | cherskiy
# Processing Record 1 of Set 6 | taltal
# Processing Record 2 of Set 6 | nichinan
# Processing Record 3 of Set 6 | halalo
# City not found. Skipping...
# 'coord'
# Processing Record 4 of Set 6 | taksimo
# Processing Record 5 of Set 6 | ntcheu
# Processing Record 6 of Set 6 | pimenta bueno
# Processing Record 7 of Set 6 | ilave
# Processing Record 8 of Set 6 | fort-shevchenko
# Processing Record 9 of Set 6 | olafsvik
# Processing Record 10 of Set 6 | hervey bay
# Processing Record 11 of Set 6 | akyab
# Processing Record 12 of Set 6 | constitucion
# Processing Record 13 of Set 6 | sabang
# Processing Record 14 of Set 6 | mahebourg
# Processing Record 15 of Set 6 | goderich
# Processing Record 16 of Set 6 | mutsamudu
# City not found. Skipping...
# 'coord'
# Processing Record 17 of Set 6 | cabedelo
# Processing Record 18 of Set 6 | hunza
# City not found. Skipping...
# 'coord'
# Processing Record 19 of Set 6 | gander
# Processing Record 20 of Set 6 | okahandja
# Processing Record 21 of Set 6 | kuala terengganu
# Processing Record 22 of Set 6 | namibe
# Processing Record 23 of Set 6 | sokolovskoye
# Processing Record 24 of Set 6 | auki
# Processing Record 25 of Set 6 | tapa
# Processing Record 26 of Set 6 | bonavista
# Processing Record 27 of Set 6 | boguchany
# Processing Record 28 of Set 6 | buluang
# Processing Record 29 of Set 6 | viljoenskroon
# Processing Record 30 of Set 6 | kloulklubed
# Processing Record 31 of Set 6 | saldanha
# Processing Record 32 of Set 6 | luba
# Processing Record 33 of Set 6 | portland
# Processing Record 34 of Set 6 | rockhampton
# Processing Record 35 of Set 6 | asau
# Processing Record 36 of Set 6 | kayerkan
# Processing Record 37 of Set 6 | spirit river
# Processing Record 38 of Set 6 | faanui
# Processing Record 39 of Set 6 | arkhara
# Processing Record 40 of Set 6 | nemuro
# Processing Record 41 of Set 6 | blythe
# Processing Record 42 of Set 6 | aripuana
# Processing Record 43 of Set 6 | north bend
# Processing Record 44 of Set 6 | hofn
# Processing Record 45 of Set 6 | alta floresta
# Processing Record 46 of Set 6 | mangla
# Processing Record 47 of Set 6 | luanda
# Processing Record 48 of Set 6 | challapata
# Processing Record 49 of Set 6 | plettenberg bay
# Processing Record 50 of Set 6 | oxapampa
# Processing Record 1 of Set 7 | pierre
# Processing Record 2 of Set 7 | port keats
# Processing Record 3 of Set 7 | basco
# Processing Record 4 of Set 7 | portel
# Processing Record 5 of Set 7 | kesennuma
# City not found. Skipping...
# 'coord'
# Processing Record 6 of Set 7 | salisbury
# Processing Record 7 of Set 7 | walvis bay
# Processing Record 8 of Set 7 | elat
# Processing Record 9 of Set 7 | oksfjord
# Processing Record 10 of Set 7 | malatya
# Processing Record 11 of Set 7 | alhama de murcia
# Processing Record 12 of Set 7 | samusu
# City not found. Skipping...
# 'coord'
# Processing Record 13 of Set 7 | aklavik
# Processing Record 14 of Set 7 | el alto
# Processing Record 15 of Set 7 | vila velha
# Processing Record 16 of Set 7 | saint-augustin
# Processing Record 17 of Set 7 | kawalu
# Processing Record 18 of Set 7 | samarai
# Processing Record 19 of Set 7 | richards bay
# Processing Record 20 of Set 7 | kota tinggi
# Processing Record 21 of Set 7 | xuddur
# Processing Record 22 of Set 7 | muros
# Processing Record 23 of Set 7 | saint-pierre
# Processing Record 24 of Set 7 | vao
# Processing Record 25 of Set 7 | verkhnyaya sinyachikha
# Processing Record 26 of Set 7 | alappuzha
# Processing Record 27 of Set 7 | new norfolk
# Processing Record 28 of Set 7 | kailua
# Processing Record 29 of Set 7 | saint-philippe
# Processing Record 30 of Set 7 | vaitupu
# City not found. Skipping...
# 'coord'
# Processing Record 31 of Set 7 | dujuma
# City not found. Skipping...
# 'coord'
# Processing Record 32 of Set 7 | kollumerland
# City not found. Skipping...
# 'coord'
# Processing Record 33 of Set 7 | oyama
# Processing Record 34 of Set 7 | betare oya
# Processing Record 35 of Set 7 | burnie
# Processing Record 36 of Set 7 | kyaikto
# Processing Record 37 of Set 7 | ratnagiri
# Processing Record 38 of Set 7 | laguna
# Processing Record 39 of Set 7 | longyearbyen
# Processing Record 40 of Set 7 | haines junction
# Processing Record 41 of Set 7 | yanan
# City not found. Skipping...
# 'coord'
# Processing Record 42 of Set 7 | tubarao
# Processing Record 43 of Set 7 | vestmannaeyjar
# Processing Record 44 of Set 7 | mayo
# Processing Record 45 of Set 7 | manica
# Processing Record 46 of Set 7 | kodinsk
# Processing Record 47 of Set 7 | tasiilaq
# Processing Record 48 of Set 7 | mehamn
# Processing Record 49 of Set 7 | chakwal
# Processing Record 50 of Set 7 | egvekinot
# Processing Record 1 of Set 8 | severo-kurilsk
# Processing Record 2 of Set 8 | anadyr
# Processing Record 3 of Set 8 | kavaratti
# Processing Record 4 of Set 8 | craig
# Processing Record 5 of Set 8 | ballina
# Processing Record 6 of Set 8 | sorong
# Processing Record 7 of Set 8 | chokurdakh
# Processing Record 8 of Set 8 | kaseda
# Processing Record 9 of Set 8 | santa marta
# Processing Record 10 of Set 8 | koyilandi
# City not found. Skipping...
# 'coord'
# Processing Record 11 of Set 8 | leh
# Processing Record 12 of Set 8 | coari
# Processing Record 13 of Set 8 | inderborskiy
# City not found. Skipping...
# 'coord'
# Processing Record 14 of Set 8 | jinka
# Processing Record 15 of Set 8 | mareeba
# Processing Record 16 of Set 8 | dawei
# Processing Record 17 of Set 8 | livenka
# Processing Record 18 of Set 8 | pallisa
# Processing Record 19 of Set 8 | henties bay
# Processing Record 20 of Set 8 | chateau-gontier
# Processing Record 21 of Set 8 | bengkulu
# Processing Record 22 of Set 8 | mnogovershinnyy
# Processing Record 23 of Set 8 | kungurtug
# Processing Record 24 of Set 8 | pleasant prairie
# Processing Record 25 of Set 8 | port lincoln
# Processing Record 26 of Set 8 | paita
# Processing Record 27 of Set 8 | rawson
# Processing Record 28 of Set 8 | weleri
# Processing Record 29 of Set 8 | srednekolymsk
# Processing Record 30 of Set 8 | inverness
# Processing Record 31 of Set 8 | stornoway
# Processing Record 32 of Set 8 | resistencia
# Processing Record 33 of Set 8 | padang
# Processing Record 34 of Set 8 | hovd
# Processing Record 35 of Set 8 | pangkalanbuun
# Processing Record 36 of Set 8 | lavrentiya
# Processing Record 37 of Set 8 | polyarnyy
# Processing Record 38 of Set 8 | den helder
# Processing Record 39 of Set 8 | mandalgovi
# Processing Record 40 of Set 8 | te anau
# Processing Record 41 of Set 8 | zhangye
# Processing Record 42 of Set 8 | mujiayingzi
# Processing Record 43 of Set 8 | dhidhdhoo
# Processing Record 44 of Set 8 | bilibino
# Processing Record 45 of Set 8 | sola
# Processing Record 46 of Set 8 | lufilufi
# Processing Record 47 of Set 8 | maracaibo
# Processing Record 48 of Set 8 | cockburn town
# Processing Record 49 of Set 8 | zolotinka
# City not found. Skipping...
# 'coord'
# Processing Record 50 of Set 8 | marsa
# Processing Record 1 of Set 9 | margate
# Processing Record 2 of Set 9 | berlevag
# Processing Record 3 of Set 9 | ailigandi
# Processing Record 4 of Set 9 | palabuhanratu
# City not found. Skipping...
# 'coord'
# Processing Record 5 of Set 9 | san francisco
# Processing Record 6 of Set 9 | acajutla
# Processing Record 7 of Set 9 | bayir
# Processing Record 8 of Set 9 | tahta
# Processing Record 9 of Set 9 | ilka
# City not found. Skipping...
# 'coord'
# Processing Record 10 of Set 9 | saint anthony
# Processing Record 11 of Set 9 | mouzakion
# City not found. Skipping...
# 'coord'
# Processing Record 12 of Set 9 | latina
# Processing Record 13 of Set 9 | winchester
# Processing Record 14 of Set 9 | praia
# Processing Record 15 of Set 9 | corning
# Processing Record 16 of Set 9 | rungata
# City not found. Skipping...
# 'coord'
# Processing Record 17 of Set 9 | kavieng
# Processing Record 18 of Set 9 | souillac
# Processing Record 19 of Set 9 | kendari
# Processing Record 20 of Set 9 | san juan
# Processing Record 21 of Set 9 | boke
# Processing Record 22 of Set 9 | araouane
# Processing Record 23 of Set 9 | zonguldak
# Processing Record 24 of Set 9 | mokhsogollokh
# Processing Record 25 of Set 9 | kazalinsk
# City not found. Skipping...
# 'coord'
# Processing Record 26 of Set 9 | cagayan de tawi-tawi
# City not found. Skipping...
# 'coord'
# Processing Record 27 of Set 9 | pundaguitan
# Processing Record 28 of Set 9 | north las vegas
# Processing Record 29 of Set 9 | kardailovo
# Processing Record 30 of Set 9 | puerto baquerizo moreno
# Processing Record 31 of Set 9 | urdzhar
# City not found. Skipping...
# 'coord'
# Processing Record 32 of Set 9 | aktau
# Processing Record 33 of Set 9 | amderma
# City not found. Skipping...
# 'coord'
# Processing Record 34 of Set 9 | cacheu
# Processing Record 35 of Set 9 | trinidad
# Processing Record 36 of Set 9 | gazli
# Processing Record 37 of Set 9 | lodja
# Processing Record 38 of Set 9 | kremenchuk
# Processing Record 39 of Set 9 | honiara
# Processing Record 40 of Set 9 | skibbereen
# Processing Record 41 of Set 9 | priiskovyy
# Processing Record 42 of Set 9 | riyadh
# Processing Record 43 of Set 9 | bosaso
# Processing Record 44 of Set 9 | santa rosa
# Processing Record 45 of Set 9 | mersing
# Processing Record 46 of Set 9 | lyubuchany
# Processing Record 47 of Set 9 | dwarka
# Processing Record 48 of Set 9 | flinders
# Processing Record 49 of Set 9 | marieville
# Processing Record 50 of Set 9 | luebo
# Processing Record 1 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 2 of Set 10 | nome
# Processing Record 3 of Set 10 | duz
# City not found. Skipping...
# 'coord'
# Processing Record 4 of Set 10 | aksarka
# Processing Record 5 of Set 10 | sao joao da barra
# Processing Record 6 of Set 10 | naftah
# City not found. Skipping...
# 'coord'
# Processing Record 7 of Set 10 | safford
# Processing Record 8 of Set 10 | valera
# Processing Record 9 of Set 10 | barra patuca
# Processing Record 10 of Set 10 | qinzhou
# Processing Record 11 of Set 10 | ponta do sol
# Processing Record 12 of Set 10 | grindavik
# Processing Record 13 of Set 10 | atasu
# Processing Record 14 of Set 10 | liusha
# Processing Record 15 of Set 10 | trofors
# Processing Record 16 of Set 10 | vanimo
# Processing Record 17 of Set 10 | port moresby
# Processing Record 18 of Set 10 | okhotsk
# Processing Record 19 of Set 10 | poum
# Processing Record 20 of Set 10 | the valley
# Processing Record 21 of Set 10 | katobu
# Processing Record 22 of Set 10 | shakawe
# Processing Record 23 of Set 10 | puerto carreno
# Processing Record 24 of Set 10 | russell
# Processing Record 25 of Set 10 | yaring
# Processing Record 26 of Set 10 | hambantota
# Processing Record 27 of Set 10 | suzu
# City not found. Skipping...
# 'coord'
# Processing Record 28 of Set 10 | tuktoyaktuk
# Processing Record 29 of Set 10 | utiroa
# City not found. Skipping...
# 'coord'
# Processing Record 30 of Set 10 | ferrol
# Processing Record 31 of Set 10 | severodvinsk
# Processing Record 32 of Set 10 | rantauprapat
# Processing Record 33 of Set 10 | dikson
# Processing Record 34 of Set 10 | alihe
# Processing Record 35 of Set 10 | sherlovaya gora
# Processing Record 36 of Set 10 | requena
# Processing Record 37 of Set 10 | sao felix do xingu
# Processing Record 38 of Set 10 | dunedin
# Processing Record 39 of Set 10 | port hedland
# Processing Record 40 of Set 10 | grande-riviere
# City not found. Skipping...
# 'coord'
# Processing Record 41 of Set 10 | nacala
# Processing Record 42 of Set 10 | kaitangata
# Processing Record 43 of Set 10 | papasquiaro
# City not found. Skipping...
# 'coord'
# Processing Record 44 of Set 10 | maumere
# Processing Record 45 of Set 10 | ahipara
# Processing Record 46 of Set 10 | lorengau
# Processing Record 47 of Set 10 | avera
# Processing Record 48 of Set 10 | lishu
# Processing Record 49 of Set 10 | uva
# Processing Record 50 of Set 10 | bela
# Processing Record 1 of Set 11 | almeirim
# Processing Record 2 of Set 11 | sao francisco
# Processing Record 3 of Set 11 | hihifo
# City not found. Skipping...
# 'coord'
# Processing Record 4 of Set 11 | tynda
# Processing Record 5 of Set 11 | aranos
# Processing Record 6 of Set 11 | mahon
# Processing Record 7 of Set 11 | gotsu
# Processing Record 8 of Set 11 | cuajinicuilapa
# Processing Record 9 of Set 11 | mount isa
# Processing Record 10 of Set 11 | black river
# Processing Record 11 of Set 11 | comodoro rivadavia
# Processing Record 12 of Set 11 | escuintla
# Processing Record 13 of Set 11 | saryshagan
# City not found. Skipping...
# 'coord'
# Processing Record 14 of Set 11 | mao
# Processing Record 15 of Set 11 | tonj
# Processing Record 16 of Set 11 | ialibu
# Processing Record 17 of Set 11 | gravelbourg
# Processing Record 18 of Set 11 | tallahassee
# Processing Record 19 of Set 11 | clyde river
# Processing Record 20 of Set 11 | sao filipe
# Processing Record 21 of Set 11 | aasiaat
# Processing Record 22 of Set 11 | kytlym
# City not found. Skipping...
# 'coord'
# Processing Record 23 of Set 11 | vila
# Processing Record 24 of Set 11 | sorland
# Processing Record 25 of Set 11 | bud
# Processing Record 26 of Set 11 | kupino
# Processing Record 27 of Set 11 | kununurra
# Processing Record 28 of Set 11 | kabanjahe
# Processing Record 29 of Set 11 | marquette
# Processing Record 30 of Set 11 | scarborough
# Processing Record 31 of Set 11 | bathsheba
# Processing Record 32 of Set 11 | korbach
# Processing Record 33 of Set 11 | frontera
# Processing Record 34 of Set 11 | ocampo
# Processing Record 35 of Set 11 | garowe
# Processing Record 36 of Set 11 | harrisonburg
# Processing Record 37 of Set 11 | hwange
# Processing Record 38 of Set 11 | kovdor
# Processing Record 39 of Set 11 | itaituba
# Processing Record 40 of Set 11 | mancio lima
# Processing Record 41 of Set 11 | san cristobal
# Processing Record 42 of Set 11 | khatanga
# Processing Record 43 of Set 11 | belfast
# Processing Record 44 of Set 11 | jalu
# Processing Record 45 of Set 11 | high level
# Processing Record 46 of Set 11 | shache
# Processing Record 47 of Set 11 | phalombe
# Processing Record 48 of Set 11 | powell river
# Processing Record 49 of Set 11 | port blair
# Processing Record 50 of Set 11 | hami
# Processing Record 1 of Set 12 | cache creek
# Processing Record 2 of Set 12 | teguldet
# Processing Record 3 of Set 12 | college
# Processing Record 4 of Set 12 | tommot
# Processing Record 5 of Set 12 | macaboboni
# City not found. Skipping...
# 'coord'
# Processing Record 6 of Set 12 | villa carlos paz
# Processing Record 7 of Set 12 | antalaha
# Processing Record 8 of Set 12 | ayan
# Processing Record 9 of Set 12 | valle de allende
# Processing Record 10 of Set 12 | aljezur
# Processing Record 11 of Set 12 | thunder bay
# Processing Record 12 of Set 12 | kindu
# Processing Record 13 of Set 12 | smithers
# Processing Record 14 of Set 12 | vrede
# Processing Record 15 of Set 12 | nouakchott
# Processing Record 16 of Set 12 | kapuskasing
# Processing Record 17 of Set 12 | bani walid
# Processing Record 18 of Set 12 | qarchi gak
# Processing Record 19 of Set 12 | port-de-paix
# City not found. Skipping...
# 'coord'
# Processing Record 20 of Set 12 | guarapari
# Processing Record 21 of Set 12 | adilcevaz
# Processing Record 22 of Set 12 | umm lajj
# Processing Record 23 of Set 12 | port augusta
# Processing Record 24 of Set 12 | prince george
# Processing Record 25 of Set 12 | druzhba
# Processing Record 26 of Set 12 | salalah
# Processing Record 27 of Set 12 | baturaja
# Processing Record 28 of Set 12 | kashary
# Processing Record 29 of Set 12 | taft
# Processing Record 30 of Set 12 | hobyo
# Processing Record 31 of Set 12 | ranong
# Processing Record 32 of Set 12 | woodward
# Processing Record 33 of Set 12 | konin
# Processing Record 34 of Set 12 | ilheus
# Processing Record 35 of Set 12 | general pico
# Processing Record 36 of Set 12 | okha
# Processing Record 37 of Set 12 | surin
# Processing Record 38 of Set 12 | gushikawa
# Processing Record 39 of Set 12 | kushiro
# Processing Record 40 of Set 12 | soe
# Processing Record 41 of Set 12 | syracuse
# Processing Record 42 of Set 12 | hasaki
# Processing Record 43 of Set 12 | izumo
# Processing Record 44 of Set 12 | westport
# Processing Record 45 of Set 12 | mwinilunga
# Processing Record 46 of Set 12 | nuuk
# Processing Record 47 of Set 12 | devils lake
# Processing Record 48 of Set 12 | nakanojo
# Processing Record 49 of Set 12 | osakarovka
# Processing Record 50 of Set 12 | bilma
# Processing Record 1 of Set 13 | silvassa
# Processing Record 2 of Set 13 | noumea
# Processing Record 3 of Set 13 | alenquer
# Processing Record 4 of Set 13 | kenai
# Processing Record 5 of Set 13 | astoria
# Processing Record 6 of Set 13 | birjand
# Processing Record 7 of Set 13 | karratha
# Processing Record 8 of Set 13 | limbang
# Processing Record 9 of Set 13 | utete
# Processing Record 10 of Set 13 | buraydah
# Processing Record 11 of Set 13 | ringas
# Processing Record 12 of Set 13 | zhengjiatun
# Processing Record 13 of Set 13 | marsh harbour
# Processing Record 14 of Set 13 | kentau
# Processing Record 15 of Set 13 | nanakuli
# Processing Record 16 of Set 13 | cacador
# Processing Record 17 of Set 13 | fez
# Processing Record 18 of Set 13 | mogadishu
# Processing Record 19 of Set 13 | eyl
# Processing Record 20 of Set 13 | san ignacio
# Processing Record 21 of Set 13 | longkou
# Processing Record 22 of Set 13 | taoudenni
# Processing Record 23 of Set 13 | areosa
# Processing Record 24 of Set 13 | sehithwa
# Processing Record 25 of Set 13 | sorvag
# City not found. Skipping...
# 'coord'
# Processing Record 26 of Set 13 | bechem
# Processing Record 27 of Set 13 | sretensk
# Processing Record 28 of Set 13 | banos
# Processing Record 29 of Set 13 | ulaanbaatar
# Processing Record 30 of Set 13 | kahului
# Processing Record 31 of Set 13 | mackay
# Processing Record 32 of Set 13 | tymovskoye
# Processing Record 33 of Set 13 | gainesville
# Processing Record 34 of Set 13 | ondjiva
# Processing Record 35 of Set 13 | yar-sale
# Processing Record 36 of Set 13 | mount gambier
# Processing Record 37 of Set 13 | fevralsk
# City not found. Skipping...
# 'coord'
# Processing Record 38 of Set 13 | iquique
# Processing Record 39 of Set 13 | guanica
# Processing Record 40 of Set 13 | thinadhoo
# Processing Record 41 of Set 13 | brest
# Processing Record 42 of Set 13 | xiashi
# Processing Record 43 of Set 13 | redcliffe
# Processing Record 44 of Set 13 | mirzapur
# Processing Record 45 of Set 13 | deception bay
# Processing Record 46 of Set 13 | panacan
# Processing Record 47 of Set 13 | lasa
# Processing Record 48 of Set 13 | awjilah
# Processing Record 49 of Set 13 | najran
# Processing Record 50 of Set 13 | vostok
# Processing Record 1 of Set 14 | preobrazheniye
# Processing Record 2 of Set 14 | derzhavinsk
# Processing Record 3 of Set 14 | marzuq
# Processing Record 4 of Set 14 | aitape
# Processing Record 5 of Set 14 | svetlaya
# Processing Record 6 of Set 14 | tumannyy
# City not found. Skipping...
# 'coord'
# Processing Record 7 of Set 14 | santa vitoria do palmar
# Processing Record 8 of Set 14 | blytheville
# Processing Record 9 of Set 14 | presidencia roque saenz pena
# Processing Record 10 of Set 14 | bereznik
# Processing Record 11 of Set 14 | nishihara
# Processing Record 12 of Set 14 | male
# Processing Record 13 of Set 14 | mbaiki
# Processing Record 14 of Set 14 | kirensk
# Processing Record 15 of Set 14 | caucaia
# Processing Record 16 of Set 14 | malmyzh
# Processing Record 17 of Set 14 | balatonfured
# Processing Record 18 of Set 14 | bolshiye uki
# City not found. Skipping...
# 'coord'
# Processing Record 19 of Set 14 | alvaraes
# Processing Record 20 of Set 14 | libertador general san martin
# Processing Record 21 of Set 14 | christchurch
# Processing Record 22 of Set 14 | kamenskoye
# City not found. Skipping...
# 'coord'
# Processing Record 23 of Set 14 | ust-tsilma
# Processing Record 24 of Set 14 | nuoro
# Processing Record 25 of Set 14 | lagunas
# Processing Record 26 of Set 14 | seguela
# Processing Record 27 of Set 14 | victor harbor
# Processing Record 28 of Set 14 | bur gabo
# City not found. Skipping...
# 'coord'
# Processing Record 29 of Set 14 | puerto escondido
# Processing Record 30 of Set 14 | la labor
# Processing Record 31 of Set 14 | wum
# Processing Record 32 of Set 14 | pingyin
# Processing Record 33 of Set 14 | lagoa
# Processing Record 34 of Set 14 | huhi
# Processing Record 35 of Set 14 | cururupu
# Processing Record 36 of Set 14 | nelson bay
# Processing Record 37 of Set 14 | waingapu
# Processing Record 38 of Set 14 | karauzyak
# City not found. Skipping...
# 'coord'
# Processing Record 39 of Set 14 | ternate
# Processing Record 40 of Set 14 | houma
# Processing Record 41 of Set 14 | roscommon
# Processing Record 42 of Set 14 | narsaq
# Processing Record 43 of Set 14 | kutum
# Processing Record 44 of Set 14 | udachnyy
# Processing Record 45 of Set 14 | kumla
# Processing Record 46 of Set 14 | tres arroyos
# Processing Record 47 of Set 14 | nchelenge
# Processing Record 48 of Set 14 | necochea
# Processing Record 49 of Set 14 | santa maria do suacui
# Processing Record 50 of Set 14 | fuglebjerg
# Processing Record 1 of Set 15 | komsomolskiy
# Processing Record 2 of Set 15 | mizdah
# Processing Record 3 of Set 15 | waitara
# Processing Record 4 of Set 15 | sao geraldo do araguaia
# Processing Record 5 of Set 15 | atar
# Processing Record 6 of Set 15 | oxelosund
# Processing Record 7 of Set 15 | bjornevatn
# Processing Record 8 of Set 15 | zhuhai
# Processing Record 9 of Set 15 | ambilobe
# Processing Record 10 of Set 15 | srandakan
# Processing Record 11 of Set 15 | otjiwarongo
# Processing Record 12 of Set 15 | deputatskiy
# Processing Record 13 of Set 15 | hay river
# Processing Record 14 of Set 15 | satitoa
# City not found. Skipping...
# 'coord'
# Processing Record 15 of Set 15 | grootfontein
# Processing Record 16 of Set 15 | ringebu
# Processing Record 17 of Set 15 | colac
# Processing Record 18 of Set 15 | arlit
# Processing Record 19 of Set 15 | biltine
# Processing Record 20 of Set 15 | sao mateus
# Processing Record 21 of Set 15 | isla mujeres
# Processing Record 22 of Set 15 | nouadhibou
# Processing Record 23 of Set 15 | lastoursville
# Processing Record 24 of Set 15 | mariana
# Processing Record 25 of Set 15 | doctor arroyo
# Processing Record 26 of Set 15 | yanliang
# Processing Record 27 of Set 15 | bhag
# Processing Record 28 of Set 15 | nokaneng
# Processing Record 29 of Set 15 | laramie
# Processing Record 30 of Set 15 | naze
# Processing Record 31 of Set 15 | wanaka
# Processing Record 32 of Set 15 | kiunga
# Processing Record 33 of Set 15 | wanning
# Processing Record 34 of Set 15 | roros
# Processing Record 35 of Set 15 | beyneu
# Processing Record 36 of Set 15 | moranbah
# Processing Record 37 of Set 15 | whitehorse
# Processing Record 38 of Set 15 | bichura
# Processing Record 39 of Set 15 | shushenskoye
# Processing Record 40 of Set 15 | svetlyy
# Processing Record 41 of Set 15 | higuey
# City not found. Skipping...
# 'coord'
# Processing Record 42 of Set 15 | phan rang
# City not found. Skipping...
# 'coord'
# Processing Record 43 of Set 15 | hutchinson
# Processing Record 44 of Set 15 | nevsehir
# Processing Record 45 of Set 15 | kelo
# Processing Record 46 of Set 15 | camocim
# Processing Record 47 of Set 15 | herat
# Processing Record 48 of Set 15 | suchilquitongo
# City not found. Skipping...
# 'coord'
# Processing Record 49 of Set 15 | nioki
# Processing Record 50 of Set 15 | kidal
# Processing Record 1 of Set 16 | beni mazar
# Processing Record 2 of Set 16 | loreto
# Processing Record 3 of Set 16 | belyy yar
# Processing Record 4 of Set 16 | ijaki
# City not found. Skipping...
# 'coord'
# Processing Record 5 of Set 16 | ziro
# Processing Record 6 of Set 16 | hinton
# Processing Record 7 of Set 16 | oranjemund
# Processing Record 8 of Set 16 | manicore
# Processing Record 9 of Set 16 | chumikan
# Processing Record 10 of Set 16 | liuhe
# Processing Record 11 of Set 16 | mackenzie
# Processing Record 12 of Set 16 | suntar
# Processing Record 13 of Set 16 | rayong
# Processing Record 14 of Set 16 | tarabuco
# Processing Record 15 of Set 16 | kondinskoye
# Processing Record 16 of Set 16 | bundaberg
# Processing Record 17 of Set 16 | nalut
# Processing Record 18 of Set 16 | choix
# Processing Record 19 of Set 16 | verkhoyansk
# Processing Record 20 of Set 16 | tazovskiy
# Processing Record 21 of Set 16 | tezu
# Processing Record 22 of Set 16 | neropolis
# Processing Record 23 of Set 16 | molinella
# Processing Record 24 of Set 16 | santiago do cacem
# Processing Record 25 of Set 16 | vylgort
# City not found. Skipping...
# 'coord'
# Processing Record 26 of Set 16 | tocopilla
# Processing Record 27 of Set 16 | rio grande
# Processing Record 28 of Set 16 | shieli
# Processing Record 29 of Set 16 | zhigansk
# Processing Record 30 of Set 16 | sept-iles
# Processing Record 31 of Set 16 | skalistyy
# City not found. Skipping...
# 'coord'
# Processing Record 32 of Set 16 | manggar
# Processing Record 33 of Set 16 | the pas
# Processing Record 34 of Set 16 | lolua
# City not found. Skipping...
# 'coord'
# Processing Record 35 of Set 16 | vitimskiy
# City not found. Skipping...
# 'coord'
# Processing Record 36 of Set 16 | ifakara
# Processing Record 37 of Set 16 | bara
# Processing Record 38 of Set 16 | vanavara
# Processing Record 39 of Set 16 | kachug
# Processing Record 40 of Set 16 | carutapera
# Processing Record 41 of Set 16 | coolum beach
# Processing Record 42 of Set 16 | kjollefjord
# Processing Record 43 of Set 16 | quatre cocos
# Processing Record 44 of Set 16 | mudyuga
# City not found. Skipping...
# 'coord'
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 718

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Jamestown      US  42.0970  -79.2353     61.34        79           1
# 1       Qaanaaq      GL  77.4840  -69.3632     19.06        59          63
# 2          Hilo      US  19.7297 -155.0900     87.28        84          90
# 3  Krasnoselkup      RU  65.7000   82.4667     33.31        90          66
# 4        Ikongo      MG -21.8833   47.4333     60.04        96          27
# 5        Touros      BR  -5.1989  -35.4608     76.10        82          39
# 6     Corsicana      US  32.0954  -96.4689     80.96        48           1
# 7     Saskylakh      RU  71.9167  114.0833     34.95        99         100
# 8    Georgetown      MY   5.4112  100.3354     80.89        87          20
# 9       Rikitea      PF -23.1203 -134.9692     73.78        72           2
#
#    Wind Speed Current Description
# 0        1.01           clear sky
# 1        8.12       broken clouds
# 2        9.22       moderate rain
# 3        8.16       broken clouds
# 4        2.59    scattered clouds
# 5       15.70    scattered clouds
# 6        5.75           clear sky
# 7       11.88     overcast clouds
# 8        3.44          few clouds
# 9       19.42           clear sky

# %%
city_data_df = city_data_df[["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",
                            "Cloudiness","Wind Speed","Current Description"]]
city_data_df.head()
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Jamestown      US  42.0970  -79.2353     61.34        79           1
# 1       Qaanaaq      GL  77.4840  -69.3632     19.06        59          63
# 2          Hilo      US  19.7297 -155.0900     87.28        84          90
# 3  Krasnoselkup      RU  65.7000   82.4667     33.31        90          66
# 4        Ikongo      MG -21.8833   47.4333     60.04        96          27
#
#    Wind Speed Current Description
# 0        1.01           clear sky
# 1        8.12       broken clouds
# 2        9.22       moderate rain
# 3        8.16       broken clouds
# 4        2.59    scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
